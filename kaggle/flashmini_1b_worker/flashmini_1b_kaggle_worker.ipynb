# %%
import os, sys
sys.path.insert(0, '/kaggle/working/src')
# %run flashmini_1b_kaggle_worker.py --run-dir /kaggle/working/flashmini_run --freeze-manifest /kaggle/working/freeze_manifest.json --smoke
